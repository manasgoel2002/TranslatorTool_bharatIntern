# %%
pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 1.7 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17398 sha256=8667fb328b49a5d18e36689fe6819a9d151c9e1ad8b23e38622cbf5debd8206c
#   Stored in directory: /Users/Manas Goel/Library/Caches/pip/wheels/39/17/6f/66a045ea3d168826074691b4b787b8f324d3f646d755443fda
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
import tkinter as tk
from googletrans import Translator

class TranslatorApp:
    def __init__(self, root):
        self.root = root
        self.root.title("English to Hindi Converter")
        
        self.translator = Translator()
        
        self.create_widgets()

    def create_widgets(self):
        self.label_input = tk.Label(self.root, text="Enter English text:")
        self.label_input.pack()

        self.input_text = tk.Text(self.root, height=5, width=50)
        self.input_text.pack()

        self.btn_translate = tk.Button(self.root, text="Convert to Hindi", command=self.translate_text)
        self.btn_translate.pack()

        self.label_output = tk.Label(self.root, text="Converted Hindi text:")
        self.label_output.pack()

        self.output_text = tk.Text(self.root, height=5, width=50, state='disabled')
        self.output_text.pack()

    def translate_text(self):
        input_text = self.input_text.get("1.0", tk.END).strip()
        if not input_text:
            return

        try:
            translation = self.translator.translate(input_text, src='en', dest='hi')
            translated_text = translation.text
            self.output_text.config(state='normal')
            self.output_text.delete('1.0', tk.END)
            self.output_text.insert(tk.END, translated_text)
            self.output_text.config(state='disabled')
        except Exception as e:
            self.output_text.config(state='normal')
            self.output_text.delete('1.0', tk.END)
            self.output_text.insert(tk.END, f"Error: {e}")
            self.output_text.config(state='disabled')

if __name__ == "__main__":
    root = tk.Tk()
    app = TranslatorApp(root)
    root.mainloop()
